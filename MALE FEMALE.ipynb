# %%
import pandas as pd

# %%
from sklearn.naive_bayes import GaussianNB

# %%
df = pd.read_csv("male female.csv")

# %%
print("Dataset preview:\n", df.head())
# Out:
# Dataset preview:
#     height  weight  shoe size  gender
# 0     181      80         44    male
# 1     177      70         43  female
# 2     160      60         38  female
# 3     154      54         37  female
# 4     166      65         40    male

# %%
X = df[['height', 'weight', 'shoe size']]
y = df['gender']

# %%
model = GaussianNB()
model.fit(X, y)
# Out:
# GaussianNB()

# %%
probabilities = model.predict_proba(X)

# %%
print("\nIndividual probabilities:")
for i, probs in enumerate(probabilities):
    print(f"Row {i+1}: Male = {probs[model.classes_.tolist().index('male')]:.2f}, Female = {probs[model.classes_.tolist().index('female')]:.2f}")
# Out:
# Individual probabilities:
# Row 1: Male = 0.85, Female = 0.15
# Row 2: Male = 0.70, Female = 0.30
# Row 3: Male = 0.07, Female = 0.93
# Row 4: Male = 0.02, Female = 0.98
# Row 5: Male = 0.25, Female = 0.75
# Row 6: Male = 0.95, Female = 0.05
# Row 7: Male = 0.37, Female = 0.63
# Row 8: Male = 0.60, Female = 0.40
# Row 9: Male = 0.83, Female = 0.17
# Row 10: Male = 0.51, Female = 0.49

# %%
avg_probs = probabilities.mean(axis=0)
print(f"\nAverage Probability:\nMale: {avg_probs[model.classes_.tolist().index('male')]:.2f}\nFemale: {avg_probs[model.classes_.tolist().index('female')]:.2f}")
# Out:
# Average Probability:
# Male: 0.51
# Female: 0.49
